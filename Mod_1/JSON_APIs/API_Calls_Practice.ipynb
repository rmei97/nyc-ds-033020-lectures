# %% [markdown]
# ## Starting Off
#
# Message me one question you have about APIs. Any question at all

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url =  'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = ''
api_key = ''

# %%
from  keys  import  client_id, api_key

# %%
print(api_key)
# Out:
# RTzp-q-TgkJW_NFQogubFvZNRDziXyoR38VbtZMWibDI-FlvB25OE7GmafFEqhTL8_Bk2HlcX24-hRWLMP7Nc6WHO_VXMXldpPBjP0LoPv5EFFELMSI2oll8njhbXHYx

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'food'

#where do you want to perform this search
location = 'Queens NY'

# what is your other parameter you want to search against
price = 2

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "price" : price,
                "limit": 50
            }

# %%
url_params
# Out:
# {'term': 'food', 'location': 'Queens+NY', 'price': 2, 'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %%
response.status_code #200 means good to go
# Out:
# 200

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
response.text
# Out:
# '{"businesses": [{"id": "-86K6KX3HlUwkWTWRO3VAQ", "alias": "kyuramen-flushing", "name": "KYURAMEN", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/DucPmagqAhaDl0ZkOKaR4w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/kyuramen-flushing?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg", "review_count": 309, "categories": [{"alias": "ramen", "title": "Ramen"}], "rating": 4.0, "coordinates": {"latitude": 40.76051, "longitude": -73.83339}, "transactions": ["delivery", "pickup", "restaurant_reservation"], "price": "$$", "location": {"address1": "133-42 37th Ave", "address2": null, "address3": "", "city": "Flushing", "zip_code": "11354", "country": "US", "state": "NY", "display_address": ["133-42 37th Ave", "Flushing, NY 11354"]}, "phone": "+19172852332", "display_phone": "(917) 285-2332", "distance": 3626.7291236741776}, {"id": "6Guo-aozyLnQFtAuP8ZXZg", "alias": "queens-comfort-astoria", "name": "Queens Comfort", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/9JGzgEzwQ8VdXJKdOZG_RA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/queens-comfort-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg", "review_count": 2123, "categories": [{"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}, {"alias": "newamerican", "title": "American (New)"}, {"alias": "comfortfood", "title": "Comfort Food"}], "rating": 4.0, "coordinates": {"latitude": 40.764527, "longitude": -73.91694}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "3618 30th Ave", "address2": "", "address3": "", "city": "Astoria", "zip_code": "11103", "country": "US", "state": "NY", "display_address": ["3618 30th Ave", "Astoria, NY 11103"]}, "phone": "+13477385119", "display_phone": "(347) 738-5119", "distance": 6532.94407586454}, {"id": "GNPne4Il-itbn2sLbvMo1g", "alias": "angel-indian-restaurant-jackson-heights", "name": "Angel Indian Restaurant", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/8HFC6t8fpwogrkAhqmXAmg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/angel-indian-restaurant-jackson-heights?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg", "review_count": 68, "categories": [{"alias": "indpak", "title": "Indian"}, {"alias": "vegetarian", "title": "Vegetarian"}, {"alias": "vegan", "title": "Vegan"}], "rating": 5.0, "coordinates": {"latitude": 40.7473069226623, "longitude": -73.8912814123575}, "transactions": ["delivery", "pickup", "restaurant_reservation"], "price": "$$", "location": {"address1": "7414 37th Rd", "address2": "", "address3": null, "city": "Jackson Heights", "zip_code": "11372", "country": "US", "state": "NY", "display_address": ["7414 37th Rd", "Jackson Heights, NY 11372"]}, "phone": "+13478480097", "display_phone": "(347) 848-0097", "distance": 3686.4065282229453}, {"id": "MhGjWgAFFyb6QMwUIkhpBQ", "alias": "metro-taco-forest-hills", "name": "Metro Taco", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/D0rTcLbgW7b0HNa-2UePDA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/metro-taco-forest-hills?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg", "review_count": 192, "categories": [{"alias": "tacos", "title": "Tacos"}, {"alias": "bars", "title": "Bars"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}], "rating": 4.5, "coordinates": {"latitude": 40.71054, "longitude": -73.85006}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "102-15 Metropolitan Ave", "address2": null, "address3": "", "city": "Forest Hills", "zip_code": "11375", "country": "US", "state": "NY", "display_address": ["102-15 Metropolitan Ave", "Forest Hills, NY 11375"]}, "phone": "+13474944947", "disp ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'x25t8G_7Lo9Wd7Grdn_HEw',
#    'alias': 'blink-fitness-125th-new-york-2',
#    'name': 'Blink Fitness - 125th',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dPDZSOyPuHm-a9Xr_6nUKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blink-fitness-125th-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 106,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.81054, 'longitude': -73.951461},
#    'transactions': [],
#    'location': {'address1': '301 W 125th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['301 W 125th St', 'New York, NY 10027']},
#    'phone': '+16462539700',
#    'display_phone': '(646) 253-9700',
#    'distance': 655.4204041035346},
#   {'id': 'JvFSaSbopX2T4mgiGl0I0A',
#    'alias': 'new-york-sports-clubs-new-york-72',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZKK4la6H97CVB4zvlGDIog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-72?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 143,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.8231394215693,
#     'longitude': -73.9420633844566},
#    'transactions': [],
#    'location': {'address1': '303 W 145th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10039',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['303 W 145th St', 'New York, NY 10039']},
#    'phone': '+12122340016',
#    'display_phone': '(212) 234-0016',
#    'distance': 995.6980342856355},
#   {'id': 'Oych8H3fLi8HCzsaQRvb_Q',
#    'alias': 'benswic-inc-new-york-2',
#    'name': 'Benswic, Inc',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ngRjyTIXxAwiEDsZ9k8jOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benswic-inc-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 7,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'summer_camps', 'title': 'Summer Camps'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.8149829, 'longitude': -73.947843},
#    'transactions': [],
#    'location': {'address1': '2473 Frederick Douglass',
#     'address2': 'Blvd Fl 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2473 Frederick Douglass',
#      'Blvd Fl 1',
#      'New York, NY 10027']},
#    'phone': '+19176593549',
#    'display_phone': '(917) 659-3549',
#    'distance': 207.92086966819383},
#   {'id': 'v1oSEKjF7EQGLQHR-zVPtw',
#    'alias': 'blink-fitness-harlem-116th-new-york',
#    'name': 'Blink Fitness - Harlem 116th',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q1m6xa3c46BIUOnAmSO3DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blink-fitness-harlem-116th-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 79,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.801442, 'longitude': -73.947629},
#    'transactions': [],
#    'location': {'address1': '27 W 116th Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 W 116th Street', 'New York, NY 10026']},
#    'phone': '+16465615454',
#    'display_phone': '(646) 561-5454',
#    'distance': 1658.1750202228752},
#   {'id': 'Z4ygiHjI9PSjEH4JlpIixw',
#    'alias': 'jtw-fit-new-york-2',
#    'name': 'JTW Fit',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bnQ1bNVGeuxewpfD2KXyvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jtw-fit-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 14,
#    'categories': [{'alias': 'boxing', 'title': 'Boxing'},
#     {'alias': 'bootcamps', 'title': 'Boot Camps'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.813054, 'longitude': -73.944908},
#    'transactions': [],
#    'location': {'address1': '2235 Adam Clayton Powell Jr Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2235 Adam Clayton Powell Jr Blvd',
#      'New York, NY 10027']},
#    'phone': '+12039368326',
#    'display_phone': '(203) 936-8326',
#    'distance': 536.9085119591264},
#   {'id': 'cP7aVia5GvvSkj9cGNZB8w',
#    'alias': 'new-york-sports-clubs-new-york-67',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/N945KOx6k45n_uMM0Rpa4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-67?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 104,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.8097714446788,
#     'longitude': -73.9517667889596},
#    'transactions': [],
#    'location': {'address1': '2311 Frederick Douglas Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2311 Frederick Douglas Blvd', 'New York, NY 10027']},
#    'phone': '+12123162500',
#    'display_phone': '(212) 316-2500',
#    'distance': 744.5325380004037},
#   {'id': 'B9hepOn0_ZN2YMuShBP-Tw',
#    'alias': 'liberated-fitness-new-york',
#    'name': 'Liberated Fitness',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/u8irLYSuIsSUcgJ_ljPdMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liberated-fitness-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 18,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8013887, 'longitude': -73.9611277},
#    'transactions': [],
#    'location': {'address1': '1005 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1005 Columbus Ave', 'New York, NY 10025']},
#    'phone': '+18578916133',
#    'display_phone': '(857) 891-6133',
#    'distance': 1914.5426419497421},
#   {'id': 'ku3CmsmQ2a81XcAVc8I1Fw',
#    'alias': 'planet-fitness-new-york-40',
#    'name': 'Planet Fitness',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9fWM1YTKxMBDmzZdJt97Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-fitness-new-york-40?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 109,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.808869, 'longitude': -73.949206},
#    'transactions': [],
#    'location': {'address1': '208 W 125th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 W 125th St', 'New York, NY 10027']},
#    'phone': '+12124972644',
#    'display_phone': '(212) 497-2644',
#    'distance': 824.3770713021464},
#   {'id': 'oAwyvQiSWGoGY9ksh4yQRw',
#    'alias': 'befitnyc-new-york',
#    'name': 'befitnyc',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rc0X-tsaoVewn_2j_YzPrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/befitnyc-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 23,
#    'categories': [{'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'cardioclasses', 'title': 'Cardio Classes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.799915, 'longitude': -73.967651},
#    'transactions': [],
#    'location': {'address1': '2726 Broadway',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2726 Broadway', 'Fl 2', 'New York, NY 10025']},
#    'phone': '+16466660978',
#    'display_phone': '(646) 666-0978',
#    'distance': 2365.7691857867985},
#   {'id': '6xuEvehxXWFvd7EGW9p5lg',
#    'alias': 'harlem-branch-ymca-new-york',
#    'name': 'Harlem Branch YMCA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CiZ8YiI899j1bMJ2Viqhsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harlem-branch-ymca-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 34,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'childcare', 'title': 'Child Care & Day Care'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.81479, 'longitude': -73.94291},
#    'transactions': [],
#    'location': {'address1': '180 W 135th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10030',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 W 135th St', 'New York, NY 10030']},
#    'phone': '+12129122100',
#    'display_phone': '(212) 912-2100',
#    'distance': 592.6934314426277},
#   {'id': 'qI2_gqEih2Zz2r9uCpqv5A',
#    'alias': 'columbia-university-dodge-fitness-center-new-york',
#    'name': 'Columbia University Dodge Fitness Center',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xepiMTHmSVzeZcpyT6ZhVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/columbia-university-dodge-fitness-center-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 46,
#    'categories': [{'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'swimmingpools', 'title': 'Swimming Pools'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.810399, 'longitude': -73.962067},
#    'transactions': [],
#    'location': {'address1': 'Columbia University',
#     'address2': '',
#     'address3': '3030 Broadway',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Columbia University',
#      '3030 Broadway',
#      'New York, NY 10027']},
#    'phone': '+12128542546',
#    'display_phone': '(212) 854-2546',
#    'distance': 1231.615303016337},
#   {'id': 'CnY_KPqSuKIFCZHsQDRG6g',
#    'alias': 'ilovekickboxing-harlem-new-york',
#    'name': 'iLoveKickboxing- Harlem',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5u4TY-kARGmyn8l7p60TGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ilovekickboxing-harlem-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 86,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'kickboxing', 'title': 'Kickboxing'},
#     {'alias': 'bootcamps', 'title': 'Boot Camps'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8017641681891,
#     'longitude': -73.9484703540802},
#    'transactions': [],
#    'location': {'address1': '47 West 116th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 West 116th St', 'New York, NY 10026']},
#    'phone': '+13473446220',
#    'display_phone': '(347) 344-6220',
#    'distance': 1616.6167127871245},
#   {'id': '-Dx2re0yYz0CZCOF8qkwIg',
#    'alias': 'hansborough-recreation-center-nyc-parks-dept-new-york',
#    'name': 'Hansborough Recreation Center - NYC Parks Dept.',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ppx0QAVSXkN6_6pkqsl5ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hansborough-recreation-center-nyc-parks-dept-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 14,
#    'categories': [{'alias': 'swimmingpools', 'title': 'Swimming Pools'},
#     {'alias': 'recreation', 'title': 'Recreation Centers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8128280639648,
#     'longitude': -73.9393157958984},
#    'transactions': [],
#    'location': {'address1': '35 W 134th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10037',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 W 134th St', 'New York, NY 10037']},
#    'phone': '+12122349603',
#    'display_phone': '(212) 234-9603',
#    'distance': 959.6072397481556},
#   {'id': '7QN3-rRh86x5vKzN2H7Bzw',
#    'alias': 'anytime-fitness-cliffside-park',
#    'name': 'Anytime Fitness',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q0O96q01DhYOb0UMPAT30g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anytime-fitness-cliffside-park?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 11,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.828273, 'longitude': -73.987101},
#    'transactions': [],
#    'location': {'address1': '1 Towne Center Dr',
#     'address2': 'Ste 1008/1009',
#     'address3': None,
#     'city': 'Cliffside Park',
#     'zip_code': '07010',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1 Towne Center Dr',
#      'Ste 1008/1009',
#      'Cliffside Park, NJ 07010']},
#    'phone': '+12019177277',
#    'display_phone': '(201) 917-7277',
#    'distance': 3421.2416289879325},
#   {'id': 'APzU2CBC7Gzwa2RTnUdAAQ',
#    'alias': 'bodystrength-fitness-new-york-2',
#    'name': 'BodyStrength Fitness',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hKLDiaqJbrZIu1CNasKnkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bodystrength-fitness-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 104,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.800996, 'longitude': -73.9674816},
#    'transactions': [],
#    'location': {'address1': '250 W 106th St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['250 W 106th St', 'Fl 2', 'New York, NY 10025']},
#    'phone': '+12123163338',
#    'display_phone': '(212) 316-3338',
#    'distance': 2266.2255951703714},
#   {'id': '0xjtdAiLrNDQy08VNtJUdg',
#    'alias': 'planet-fitness-new-york-37',
#    'name': 'Planet Fitness',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9X_H7HJGL0CiuwbYpqWmTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-fitness-new-york-37?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 74,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.83455, 'longitude': -73.94504},
#    'transactions': [],
#    'location': {'address1': '3799 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3799 Broadway', 'New York, NY 10032']},
#    'phone': '+12123360830',
#    'display_phone': '(212) 336-0830',
#    'distance': 2068.974971700407},
#   {'id': 'XsCcKxJQThO__zfMCZHPig',
#    'alias': 'blink-fitness-bronx-18',
#    'name': 'Blink Fitness',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3Ouj2lYcBHq1hms_fMWlmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blink-fitness-bronx-18?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 7,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.816857399717, 'longitude': -73.917223849458},
#    'transactions': [],
#    'location': {'address1': '570 Melrose Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Bronx',
#     'zip_code': '10455',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['570 Melrose Ave', 'Bronx, NY 10455']},
#    'phone': '+13473386459',
#    'display_phone': '(347) 338-6459',
#    'distance': 2730.4705003243166},
#   {'id': 'Z42S9ucaD5xIvdGB_vkCTA',
#    'alias': 'the-monterey-health-club-new-york',
#    'name': 'The Monterey Health Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8BX-USsXM3xdJ66NyByoIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monterey-health-club-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 4,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78557, 'longitude': -73.94975},
#    'transactions': [],
#    'location': {'address1': '175 E 96th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['175 E 96th St', 'New York, NY 10128']},
#    'phone': '+12129968200',
#    'display_phone': '(212) 996-8200',
#    'distance': 3402.7444065892914},
#   {'id': 'G3Pi--DpJcsV5xS4HWp8Qw',
#    'alias': 'new-york-sports-clubs-new-york-82',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xAaxpvfGKiCBgQYExTYKSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-82?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 58,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.800343, 'longitude': -73.946862},
#    'transactions': [],
#    'location': {'address1': '1400 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1400 5th Ave', 'New York, NY 10026']},
#    'phone': '+12127221185',
#    'display_phone': '(212) 722-1185',
#    'distance': 1787.1302832593587},
#   {'id': 'jjsE8j5JYzDJjlLitVHO_g',
#    'alias': 'orangetheory-fitness-edgewater-edgewater',
#    'name': 'Orangetheory Fitness Edgewater',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/so1A_JmV9epejRqSM-OXzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orangetheory-fitness-edgewater-edgewater?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 137,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'bootcamps', 'title': 'Boot Camps'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8188095, 'longitude': -73.9774704},
#    'transactions': [],
#    'location': {'address1': '725 River Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Edgewater',
#     'zip_code': '07020',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['725 River Rd', 'Edgewater, NJ 07020']},
#    'phone': '+12012126388',
#    'display_phone': '(201) 212-6388',
#    'distance': 2363.6809342884226}],
#  'total': 314,
#  'region': {'center': {'longitude': -73.94966125488281,
#    'latitude': 40.81627479820395}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'x25t8G_7Lo9Wd7Grdn_HEw',
#    'alias': 'blink-fitness-125th-new-york-2',
#    'name': 'Blink Fitness - 125th',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dPDZSOyPuHm-a9Xr_6nUKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blink-fitness-125th-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 106,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.81054, 'longitude': -73.951461},
#    'transactions': [],
#    'location': {'address1': '301 W 125th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['301 W 125th St', 'New York, NY 10027']},
#    'phone': '+16462539700',
#    'display_phone': '(646) 253-9700',
#    'distance': 655.4204041035346},
#   {'id': 'JvFSaSbopX2T4mgiGl0I0A',
#    'alias': 'new-york-sports-clubs-new-york-72',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZKK4la6H97CVB4zvlGDIog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-72?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 143,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.8231394215693,
#     'longitude': -73.9420633844566},
#    'transactions': [],
#    'location': {'address1': '303 W 145th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10039',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['303 W 145th St', 'New York, NY 10039']},
#    'phone': '+12122340016',
#    'display_phone': '(212) 234-0016',
#    'distance': 995.6980342856355},
#   {'id': 'Oych8H3fLi8HCzsaQRvb_Q',
#    'alias': 'benswic-inc-new-york-2',
#    'name': 'Benswic, Inc',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ngRjyTIXxAwiEDsZ9k8jOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benswic-inc-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 7,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'summer_camps', 'title': 'Summer Camps'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.8149829, 'longitude': -73.947843},
#    'transactions': [],
#    'location': {'address1': '2473 Frederick Douglass',
#     'address2': 'Blvd Fl 1',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2473 Frederick Douglass',
#      'Blvd Fl 1',
#      'New York, NY 10027']},
#    'phone': '+19176593549',
#    'display_phone': '(917) 659-3549',
#    'distance': 207.92086966819383},
#   {'id': 'v1oSEKjF7EQGLQHR-zVPtw',
#    'alias': 'blink-fitness-harlem-116th-new-york',
#    'name': 'Blink Fitness - Harlem 116th',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q1m6xa3c46BIUOnAmSO3DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blink-fitness-harlem-116th-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 79,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.801442, 'longitude': -73.947629},
#    'transactions': [],
#    'location': {'address1': '27 W 116th Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 W 116th Street', 'New York, NY 10026']},
#    'phone': '+16465615454',
#    'display_phone': '(646) 561-5454',
#    'distance': 1658.1750202228752},
#   {'id': 'Z4ygiHjI9PSjEH4JlpIixw',
#    'alias': 'jtw-fit-new-york-2',
#    'name': 'JTW Fit',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bnQ1bNVGeuxewpfD2KXyvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jtw-fit-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 14,
#    'categories': [{'alias': 'boxing', 'title': 'Boxing'},
#     {'alias': 'bootcamps', 'title': 'Boot Camps'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.813054, 'longitude': -73.944908},
#    'transactions': [],
#    'location': {'address1': '2235 Adam Clayton Powell Jr Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2235 Adam Clayton Powell Jr Blvd',
#      'New York, NY 10027']},
#    'phone': '+12039368326',
#    'display_phone': '(203) 936-8326',
#    'distance': 536.9085119591264},
#   {'id': 'cP7aVia5GvvSkj9cGNZB8w',
#    'alias': 'new-york-sports-clubs-new-york-67',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/N945KOx6k45n_uMM0Rpa4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-67?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 104,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.8097714446788,
#     'longitude': -73.9517667889596},
#    'transactions': [],
#    'location': {'address1': '2311 Frederick Douglas Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2311 Frederick Douglas Blvd', 'New York, NY 10027']},
#    'phone': '+12123162500',
#    'display_phone': '(212) 316-2500',
#    'distance': 744.5325380004037},
#   {'id': 'B9hepOn0_ZN2YMuShBP-Tw',
#    'alias': 'liberated-fitness-new-york',
#    'name': 'Liberated Fitness',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/u8irLYSuIsSUcgJ_ljPdMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liberated-fitness-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 18,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.8013887, 'longitude': -73.9611277},
#    'transactions': [],
#    'location': {'address1': '1005 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1005 Columbus Ave', 'New York, NY 10025']},
#    'phone': '+18578916133',
#    'display_phone': '(857) 891-6133',
#    'distance': 1914.5426419497421},
#   {'id': 'ku3CmsmQ2a81XcAVc8I1Fw',
#    'alias': 'planet-fitness-new-york-40',
#    'name': 'Planet Fitness',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9fWM1YTKxMBDmzZdJt97Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-fitness-new-york-40?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 109,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.808869, 'longitude': -73.949206},
#    'transactions': [],
#    'location': {'address1': '208 W 125th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 W 125th St', 'New York, NY 10027']},
#    'phone': '+12124972644',
#    'display_phone': '(212) 497-2644',
#    'distance': 824.3770713021464},
#   {'id': 'oAwyvQiSWGoGY9ksh4yQRw',
#    'alias': 'befitnyc-new-york',
#    'name': 'befitnyc',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rc0X-tsaoVewn_2j_YzPrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/befitnyc-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 23,
#    'categories': [{'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'cardioclasses', 'title': 'Cardio Classes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.799915, 'longitude': -73.967651},
#    'transactions': [],
#    'location': {'address1': '2726 Broadway',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2726 Broadway', 'Fl 2', 'New York, NY 10025']},
#    'phone': '+16466660978',
#    'display_phone': '(646) 666-0978',
#    'distance': 2365.7691857867985},
#   {'id': '6xuEvehxXWFvd7EGW9p5lg',
#    'alias': 'harlem-branch-ymca-new-york',
#    'name': 'Harlem Branch YMCA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CiZ8YiI899j1bMJ2Viqhsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harlem-branch-ymca-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 34,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'childcare', 'title': 'Child Care & Day Care'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.81479, 'longitude': -73.94291},
#    'transactions': [],
#    'location': {'address1': '180 W 135th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10030',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['180 W 135th St', 'New York, NY 10030']},
#    'phone': '+12129122100',
#    'display_phone': '(212) 912-2100',
#    'distance': 592.6934314426277},
#   {'id': 'qI2_gqEih2Zz2r9uCpqv5A',
#    'alias': 'columbia-university-dodge-fitness-center-new-york',
#    'name': 'Columbia University Dodge Fitness Center',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xepiMTHmSVzeZcpyT6ZhVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/columbia-university-dodge-fitness-center-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 46,
#    'categories': [{'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'swimmingpools', 'title': 'Swimming Pools'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.810399, 'longitude': -73.962067},
#    'transactions': [],
#    'location': {'address1': 'Columbia University',
#     'address2': '',
#     'address3': '3030 Broadway',
#     'city': 'New York',
#     'zip_code': '10027',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Columbia University',
#      '3030 Broadway',
#      'New York, NY 10027']},
#    'phone': '+12128542546',
#    'display_phone': '(212) 854-2546',
#    'distance': 1231.615303016337},
#   {'id': 'CnY_KPqSuKIFCZHsQDRG6g',
#    'alias': 'ilovekickboxing-harlem-new-york',
#    'name': 'iLoveKickboxing- Harlem',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5u4TY-kARGmyn8l7p60TGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ilovekickboxing-harlem-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 86,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'kickboxing', 'title': 'Kickboxing'},
#     {'alias': 'bootcamps', 'title': 'Boot Camps'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8017641681891,
#     'longitude': -73.9484703540802},
#    'transactions': [],
#    'location': {'address1': '47 West 116th St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 West 116th St', 'New York, NY 10026']},
#    'phone': '+13473446220',
#    'display_phone': '(347) 344-6220',
#    'distance': 1616.6167127871245},
#   {'id': '-Dx2re0yYz0CZCOF8qkwIg',
#    'alias': 'hansborough-recreation-center-nyc-parks-dept-new-york',
#    'name': 'Hansborough Recreation Center - NYC Parks Dept.',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ppx0QAVSXkN6_6pkqsl5ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hansborough-recreation-center-nyc-parks-dept-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 14,
#    'categories': [{'alias': 'swimmingpools', 'title': 'Swimming Pools'},
#     {'alias': 'recreation', 'title': 'Recreation Centers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8128280639648,
#     'longitude': -73.9393157958984},
#    'transactions': [],
#    'location': {'address1': '35 W 134th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10037',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 W 134th St', 'New York, NY 10037']},
#    'phone': '+12122349603',
#    'display_phone': '(212) 234-9603',
#    'distance': 959.6072397481556},
#   {'id': '7QN3-rRh86x5vKzN2H7Bzw',
#    'alias': 'anytime-fitness-cliffside-park',
#    'name': 'Anytime Fitness',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q0O96q01DhYOb0UMPAT30g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anytime-fitness-cliffside-park?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 11,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.828273, 'longitude': -73.987101},
#    'transactions': [],
#    'location': {'address1': '1 Towne Center Dr',
#     'address2': 'Ste 1008/1009',
#     'address3': None,
#     'city': 'Cliffside Park',
#     'zip_code': '07010',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1 Towne Center Dr',
#      'Ste 1008/1009',
#      'Cliffside Park, NJ 07010']},
#    'phone': '+12019177277',
#    'display_phone': '(201) 917-7277',
#    'distance': 3421.2416289879325},
#   {'id': 'APzU2CBC7Gzwa2RTnUdAAQ',
#    'alias': 'bodystrength-fitness-new-york-2',
#    'name': 'BodyStrength Fitness',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hKLDiaqJbrZIu1CNasKnkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bodystrength-fitness-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 104,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'yoga', 'title': 'Yoga'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.800996, 'longitude': -73.9674816},
#    'transactions': [],
#    'location': {'address1': '250 W 106th St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['250 W 106th St', 'Fl 2', 'New York, NY 10025']},
#    'phone': '+12123163338',
#    'display_phone': '(212) 316-3338',
#    'distance': 2266.2255951703714},
#   {'id': '0xjtdAiLrNDQy08VNtJUdg',
#    'alias': 'planet-fitness-new-york-37',
#    'name': 'Planet Fitness',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9X_H7HJGL0CiuwbYpqWmTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/planet-fitness-new-york-37?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 74,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.83455, 'longitude': -73.94504},
#    'transactions': [],
#    'location': {'address1': '3799 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3799 Broadway', 'New York, NY 10032']},
#    'phone': '+12123360830',
#    'display_phone': '(212) 336-0830',
#    'distance': 2068.974971700407},
#   {'id': 'XsCcKxJQThO__zfMCZHPig',
#    'alias': 'blink-fitness-bronx-18',
#    'name': 'Blink Fitness',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3Ouj2lYcBHq1hms_fMWlmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blink-fitness-bronx-18?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 7,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.816857399717, 'longitude': -73.917223849458},
#    'transactions': [],
#    'location': {'address1': '570 Melrose Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Bronx',
#     'zip_code': '10455',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['570 Melrose Ave', 'Bronx, NY 10455']},
#    'phone': '+13473386459',
#    'display_phone': '(347) 338-6459',
#    'distance': 2730.4705003243166},
#   {'id': 'Z42S9ucaD5xIvdGB_vkCTA',
#    'alias': 'the-monterey-health-club-new-york',
#    'name': 'The Monterey Health Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8BX-USsXM3xdJ66NyByoIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-monterey-health-club-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 4,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78557, 'longitude': -73.94975},
#    'transactions': [],
#    'location': {'address1': '175 E 96th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['175 E 96th St', 'New York, NY 10128']},
#    'phone': '+12129968200',
#    'display_phone': '(212) 996-8200',
#    'distance': 3402.7444065892914},
#   {'id': 'G3Pi--DpJcsV5xS4HWp8Qw',
#    'alias': 'new-york-sports-clubs-new-york-82',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xAaxpvfGKiCBgQYExTYKSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-82?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 58,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.800343, 'longitude': -73.946862},
#    'transactions': [],
#    'location': {'address1': '1400 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10026',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1400 5th Ave', 'New York, NY 10026']},
#    'phone': '+12127221185',
#    'display_phone': '(212) 722-1185',
#    'distance': 1787.1302832593587},
#   {'id': 'jjsE8j5JYzDJjlLitVHO_g',
#    'alias': 'orangetheory-fitness-edgewater-edgewater',
#    'name': 'Orangetheory Fitness Edgewater',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/so1A_JmV9epejRqSM-OXzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orangetheory-fitness-edgewater-edgewater?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 137,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'bootcamps', 'title': 'Boot Camps'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8188095, 'longitude': -73.9774704},
#    'transactions': [],
#    'location': {'address1': '725 River Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Edgewater',
#     'zip_code': '07020',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['725 River Rd', 'Edgewater, NJ 07020']},
#    'phone': '+12012126388',
#    'display_phone': '(201) 212-6388',
#    'distance': 2363.6809342884226}],
#  'total': 314,
#  'region': {'center': {'longitude': -73.94966125488281,
#    'latitude': 40.81627479820395}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = json.loads(response.text)

# %%
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-5d011b471556> in <module>
# ----> 1 data['offset']
#
# KeyError: 'offset'

# %% [markdown]
# What are the keys in this dictionary and the datatypes of their values.

# %%
# your code here
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
[print(f'{key}\n {type(data[key])}') for key in data]
# Out:
# businesses
#  <class 'list'>
# total
#  <class 'int'>
# region
#  <class 'dict'>
# [None, None, None]

# %%
for k,v in data.items():
    print(k)
    print(type(v))
# Out:
# businesses
# <class 'list'>
# total
# <class 'int'>
# region
# <class 'dict'>

# %% [markdown]
# How many results did our query return?

# %%
print(len(data['businesses'])) #50 because we limited it to 50
print(data['total']) #how many results come positive
#we only see the 50 out of the total 19700
# Out:
# 50
# 19700

# %% [markdown]
# How many businesses were returned from the API call?

# %%
____
# Out:
# 20

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
business = data['businesses'][1]

# %%
business
# Out:
# {'id': '6Guo-aozyLnQFtAuP8ZXZg',
#  'alias': 'queens-comfort-astoria',
#  'name': 'Queens Comfort',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9JGzgEzwQ8VdXJKdOZG_RA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/queens-comfort-astoria?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#  'review_count': 2123,
#  'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#   {'alias': 'newamerican', 'title': 'American (New)'},
#   {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 40.764527, 'longitude': -73.91694},
#  'transactions': ['delivery', 'pickup'],
#  'price': '$$',
#  'location': {'address1': '3618 30th Ave',
#   'address2': '',
#   'address3': '',
#   'city': 'Astoria',
#   'zip_code': '11103',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['3618 30th Ave', 'Astoria, NY 11103']},
#  'phone': '+13477385119',
#  'display_phone': '(347) 738-5119',
#  'distance': 6532.94407586454}

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
biz_list = [business['name'], 
            ' '.join(business['location']['display_address']), #using join since arg will be a 'n' list of values
            business['price']]

# %%
biz_list
# Out:
# ['Queens Comfort', '3618 30th Ave Astoria, NY 11103', '$$']

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    parsed_data = []
    
    # loop through our business and parse each individual business
    for business in list_of_data:
        print(business['name'])
        biz_list = [business['name'], 
            ' '.join(business['location']['display_address']), #using join since arg will be a 'n' list of values
            business['price']]
        
    # in the loop, add each individual parsed  business to our data container
        parsed_data.append(biz_list)

    # return the container with all of the parsed results
    return parsed_data

# %%
parsed_data = parse_data(data['businesses'])
# Out:
# KYURAMEN
# Queens Comfort
# Angel Indian Restaurant
# Metro Taco
# The Alcove
# Fat Boys Burrito
# Mama Lee
# Hot Peppers
# Burrito Republic
# Astoria Seafood and Grill
# Sugar Freak
# La Vecina
# KXBURGERBAR
# Lamoon
# Taste Good Malaysian Cuisine
# Tony's Beechhurst Deli
# Chicken Lovers
# Laly's Restaurant
# La Rotisserie du Coin
# Emoji Burger
# Taste of Heaven
# Bangkok Avenue
# Lahi
# Trestle
# Gossip House
# Sweet Chick
# Amar Peruvian Kitchen
# I Am Nacho Mama
# Sami's Kabab House
# Sik Gaek
# Eva's Kitchen
# Long King House
# Mis Tierras Colombianas
# Jora Restaurant & Bar
# The Shady Lady
# Tito Rad's Grill
# Khao Nom
# Veggie Castle II
# Cipollina Gourmet
# Mito
# Memories of Shanghai
# LIC Market
# Roll-N-Roaster
# The Basac
# The Local Press
# Forma Pasta Factory
# La Boulangerie
# Pahal Zan
# Papa's Kitchen
# Williamsburg Smorgasburg - Saturday

# %%
import pandas as pd

# %%
pd.DataFrame(parsed_data)#only one paramater doesn't have columns!
# Out:
#                                       0  \
# 0                              KYURAMEN
# 1                        Queens Comfort
# 2               Angel Indian Restaurant
# 3                            Metro Taco
# 4                            The Alcove
# 5                      Fat Boys Burrito
# 6                              Mama Lee
# 7                           Hot Peppers
# 8                      Burrito Republic
# 9             Astoria Seafood and Grill
# 10                          Sugar Freak
# 11                            La Vecina
# 12                          KXBURGERBAR
# 13                               Lamoon
# 14         Taste Good Malaysian Cuisine
# 15               Tony's Beechhurst Deli
# 16                       Chicken Lovers
# 17                    Laly's Restaurant
# 18                La Rotisserie du Coin
# 19                         Emoji Burger
# 20                      Taste of Heaven
# 21                       Bangkok Avenue
# 22                                 Lahi
# 23                              Trestle
# 24                         Gossip House
# 25                          Sweet Chick
# 26                Amar Peruvian Kitchen
# 27                      I Am Nacho Mama
# 28                   Sami's Kabab House
# 29                             Sik Gaek
# 30                        Eva's Kitchen
# 31                      Long King House
# 32              Mis Tierras Colombianas
# 33                Jora Restaurant & Bar
# 34                       The Shady Lady
# 35                     Tito Rad's Grill
# 36                             Khao Nom
# 37                     Veggie Castle II
# 38                    Cipollina Gourmet
# 39                                 Mito
# 40                 Memories of Shanghai
# 41                           LIC Market
# 42                       Roll-N-Roaster
# 43                            The Basac
# 44                      The Local Press
# 45                  Forma Pasta Factory
# 46                       La Boulangerie
# 47                            Pahal Zan
# 48                       Papa's Kitchen
# 49  Williamsburg Smorgasburg - Saturday
#
#                                                     1   2
# 0                  133-42 37th Ave Flushing, NY 11354  $$
# 1                     3618 30th Ave Astoria, NY 11103  $$
# 2              7414 37th Rd Jackson Heights, NY 11372  $$
# 3      102-15 Metropolitan Ave Forest Hills, NY 11375  $$
# 4                   41-11 49th St Sunnyside, NY 11104  $$
# 5                  2496 Merrick Rd Bellmore, NY 11710  $$
# 6                   213-12 48th Ave Bayside, NY 11364  $$
# 7    78-33 Springfield Blvd Oakland Gardens, NY 11364  $$
# 8                  59-15 71st Ave Ridgewood, NY 11385  $$
# 9                 25-79 Steinway St Astoria, NY 11103  $$
# 10                   37-11 30th Ave Astoria, NY 11103  $$
# 11                30-66 Steinway St Astoria, NY 11103  $$
# 12               29-04 Ditmars Blvd Astoria, NY 11105  $$
# 13                   8140 Broadway Elmhurst, NY 11373  $$
# 14                  82-18 45th Ave Elmhurst, NY 11373  $$
# 15                 1118 154th St Whitestone, NY 11357  $$
# 16              21509 Northern Blvd Bayside, NY 11361  $$
# 17      75-19 Roosevelt Ave Jackson Heights, NY 11372  $$
# 18              107-10 71st Rd Forest Hills, NY 11375  $$
# 19           80-07 37th Ave Jackson Heights, NY 11372  $$
# 20                  251 Jackson St Brooklyn, NY 11211  $$
# 21         253-21 Northern Blvd Little Neck, NY 11362  $$
# 22               51-24 Van Loon St Elmhurst, NY 11373  $$
# 23                   34-02 Broadway Astoria, NY 11106  $$
# 24            147-46 Northern Blvd Flushing, NY 11354  $$
# 25       46-42 Vernon Blvd Long Island City, NY 11101  $$
# 26       68-60 Austin St Ste 6 Forest Hills, NY 11375  $$
# 27             7 W Village Green Hicksville, NY 11801  $$
# 28                35-57 Crescent St Astoria, NY 11106  $$
# 29             49-11 Roosevelt Ave Woodside, NY 11377  $$
# 30            12036 Queens Blvd Kew Gardens, NY 11415  $$
# 31   15-26 College Point Blvd College Point, NY 11356  $$
# 32             54-08 Roosevelt Ave Woodside, NY 11377  $$
# 33           47-46 11th St Long Island City, NY 11101  $$
# 34                   34-19 30th Ave Astoria, NY 11103  $$
# 35               49-10 Queens Blvd Woodside, NY 11377  $$
# 36                   42-06 77th St Elmhurst, NY 11373  $$
# 37    13209 Liberty Ave South Richmond Hill, NY 11419  $$
# 38          116-09 Queens Blvd Forest Hills, NY 11375  $$
# 39              64-18 108th St Forest Hills, NY 11375  $$
# 40             68-60 Austin St Forest Hills, NY 11375  $$
# 41           21-52 44th Dr Long Island City, NY 11101  $$
# 42                 2901 Emmons Ave Brooklyn, NY 11235  $$
# 43            158-09 Northern Blvd Flushing, NY 11358  $$
# 44           92-15 Rockaway Blvd Ozone Park, NY 11417  $$
# 45                  14 Bedford Ave Brooklyn, NY 11222  $$
# 46              109-01 72nd Rd Forest Hills, NY 11375  $$
# 47             106-12 71st Ave Forest Hills, NY 11375  $$
# 48             3707 83rd St Jackson Heights, NY 11372  $$
# 49  90 Kent Ave East River State Park Brooklyn, NY...  $$

# %%
columns = ['Name','Address','Price']

# %%
df = pd.DataFrame(parsed_data, columns = columns)#only one paramater doesn't have columns!

# %%
df.to_csv('yelp_data.csv')
